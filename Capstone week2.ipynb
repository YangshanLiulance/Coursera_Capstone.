# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# import the data into the notebook

# %%
df = pd.read_csv('/Users/liuyangshan/Desktop/mapdata.csv', header = 0)

# %%
df.head()
# Out:
#   PostalCode          Borough                                     Neighborhood
# 0        M4N  Central Toronto                                    Lawrence Park
# 1        M5N  Central Toronto                                         Roselawn
# 2        M4P  Central Toronto                                 Davisville North
# 3        M5P  Central Toronto  Forest Hill North & West, Forest Hill Road Park
# 4        M4R  Central Toronto                North Toronto West, Lawrence Park

# %%
df2 = pd.read_csv('/Users/liuyangshan/Desktop/Geospatial_Coordinates2.csv')

# %% [markdown]
# check how the data looks like

# %%
df2
# Out:
#     PostalCode   Latitude  Longitude
# 0          M1B  43.806686 -79.194353
# 1          M1C  43.784535 -79.160497
# 2          M1E  43.763573 -79.188711
# 3          M1G  43.770992 -79.216917
# 4          M1H  43.773136 -79.239476
# ..         ...        ...        ...
# 98         M9N  43.706876 -79.518188
# 99         M9P  43.696319 -79.532242
# 100        M9R  43.688905 -79.554724
# 101        M9V  43.739416 -79.588437
# 102        M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# merge the data by postal code

# %%
dfm = df.merge(df2, on=['PostalCode'])

# %%
dfm
# Out:
#     PostalCode          Borough  \
# 0          M4N  Central Toronto
# 1          M5N  Central Toronto
# 2          M4P  Central Toronto
# 3          M5P  Central Toronto
# 4          M4R  Central Toronto
# ..         ...              ...
# 98         M6C             York
# 99         M6E             York
# 100        M6M             York
# 101        M6N             York
# 102        M9N             York
#
#                                          Neighborhood   Latitude  Longitude
# 0                                       Lawrence Park  43.728020 -79.388790
# 1                                            Roselawn  43.711695 -79.416936
# 2                                    Davisville North  43.712751 -79.390197
# 3     Forest Hill North & West, Forest Hill Road Park  43.696948 -79.411307
# 4                   North Toronto West, Lawrence Park  43.715383 -79.405678
# ..                                                ...        ...        ...
# 98                                 Humewood-Cedarvale  43.693781 -79.428191
# 99                                Caledonia-Fairbanks  43.689026 -79.453512
# 100  Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 101                     Runnymede, The Junction North  43.673185 -79.487262
# 102                                            Weston  43.706876 -79.518188
#
# [103 rows x 5 columns]

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.8.1-py2.py3-none-any.whl (962 kB)
#      |████████████████████████████████| 962 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23.0 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from geopandas) (1.0.1)
# Collecting pyproj>=2.2.0
#   Downloading pyproj-2.6.1.post1-cp37-cp37m-macosx_10_9_x86_64.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 17.6 MB/s eta 0:00:01
# Collecting shapely
#   Downloading Shapely-1.7.1-cp37-cp37m-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 11.7 MB/s eta 0:00:01
# Collecting fiona
#   Downloading Fiona-1.8.17-cp37-cp37m-macosx_10_9_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 13.5 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.23.0->geopandas) (1.18.1)
# Collecting cligj>=0.5
#   Downloading cligj-0.6.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: click<8,>=4.0 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (7.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: six>=1.7 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (1.14.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: attrs>=17 in /Users/liuyangshan/opt/anaconda3/lib/python3.7/site-packages (from fiona->geopandas) (19.3.0)
# Installing collected packages: pyproj, shapely, cligj, click-plugins, munch, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.6.0 fiona-1.8.17 geopandas-0.8.1 munch-2.5.0 pyproj-2.6.1.post1 shapely-1.7.1

# %%
import geopandas as gpd           # importing geopandas
import matplotlib.pyplot as plt

# %%
import folium

# %%
borough = dfm.iloc[:,1]
latitude = dfm.iloc[:,3]
longtitude = dfm.iloc[:,4]
# Out:
# 0     -79.388790
# 1     -79.416936
# 2     -79.390197
# 3     -79.411307
# 4     -79.405678
#          ...
# 98    -79.428191
# 99    -79.453512
# 100   -79.476013
# 101   -79.487262
# 102   -79.518188
# Name: Longitude, Length: 103, dtype: float64

# %%
toronto_map = folium.Map(location = [43.651070, -79.347015], zoom_start = 10)
dots = folium.map.FeatureGroup()
dots.add_child(folium.features.CircleMarker([43.728020,-79.388790],radius = 2,color = 'Red',fill_color = 'Red'))
toronto_map.add_child(dots)
folium.Marker([43.728020,-79.388790],popup = 'Central Toronto').add_to(toronto_map)
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
toronto_map = folium.Map(location = [43.651070, -79.347015], zoom_start = 10)
dots = folium.map.FeatureGroup()
for i in range(103): 
    dots.add_child(folium.features.CircleMarker([latitude[i],longtitude[i]],radius = 2,color = 'Red',fill_color = 'Red'))
    toronto_map.add_child(dots)
    folium.Marker([latitude[i],longtitude[i]],popup = str(borough[i])).add_to(toronto_map)
    
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
